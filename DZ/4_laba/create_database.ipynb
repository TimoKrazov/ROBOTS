# %%
import sqlite3

# %%
data = [(1, 'Alpha Platform', 'Алексей Иванов', 1250000.00, 1187500.00, '2026-08-15'),
(2, 'Beta System', 'Мария Петрова', 950000.00, 855000.00, '2026-11-22'),
(3, 'Gamma Solution', 'Иван Сидоров', 2100000.00, 1995000.00, '2027-01-30'),
(4, 'Delta Initiative', 'Елена Кузнецова', 780000.00, 702000.00, '2026-09-10'),
(5, 'Epsilon Framework', 'Дмитрий Смирнов', 1650000.00, 1567500.00, '2027-03-05'),
(6, 'Nexus Project', 'Ольга Попова', 3200000.00, 2880000.00, '2026-12-01'),
(7, 'Vertex Program', 'Сергей Васильев', 890000.00, 801000.00, '2026-10-18'),
(8, 'Apex Module', 'Анна Фёдорова', 1420000.00, 1349000.00, '2027-02-14'),
(9, 'Summit Network', 'Андрей Морозов', 2750000.00, 2612500.00, '2026-07-25'),
(10, 'Horizon Engine', 'Татьяна Никитина', 670000.00, 603000.00, '2026-11-05'),
(11, 'Quantum Suite', 'Алексей Петров', 1890000.00, 1795500.00, '2027-04-12'),
(12, 'Nova Hub', 'Мария Сидорова', 920000.00, 828000.00, '2026-08-30'),
(13, 'Pioneer Cloud', 'Иван Кузнецов', 3100000.00, 2945000.00, '2027-01-20'),
(14, 'Vanguard Analytics', 'Елена Смирнова', 760000.00, 684000.00, '2026-10-03'),
(15, 'Infinity Portal', 'Дмитрий Попов', 1340000.00, 1273000.00, '2026-12-18'),
(16, 'Zenith Dashboard', 'Ольга Васильева', 2250000.00, 2137500.00, '2027-03-22'),
(17, 'Orion AI', 'Сергей Фёдоров', 540000.00, 486000.00, '2026-09-28'),
(18, 'Aurora ERP', 'Анна Морозова', 1780000.00, 1691000.00, '2027-02-09'),
(19, 'Catalyst CRM', 'Андрей Никитин', 2950000.00, 2802500.00, '2026-11-14'),
(20, 'Synergy Mobile', 'Татьяна Иванова', 830000.00, 747000.00, '2026-07-19'),
(21, 'Alpha System', 'Алексей Сидоров', 1120000.00, 1064000.00, '2026-10-25'),
(22, 'Beta Framework', 'Мария Кузнецова', 2450000.00, 2327500.00, '2027-01-08'),
(23, 'Gamma Project', 'Иван Смирнов', 690000.00, 621000.00, '2026-12-05'),
(24, 'Delta Program', 'Елена Попова', 1580000.00, 1501000.00, '2027-04-01'),
(25, 'Epsilon Module', 'Дмитрий Васильев', 3300000.00, 3135000.00, '2026-08-22'),
(26, 'Nexus Network', 'Ольга Фёдорова', 720000.00, 648000.00, '2026-11-17'),
(27, 'Vertex Engine', 'Сергей Морозов', 1950000.00, 1852500.00, '2027-02-28'),
(28, 'Apex Suite', 'Анна Никитина', 880000.00, 792000.00, '2026-09-12'),
(29, 'Summit Hub', 'Андрей Иванов', 2670000.00, 2536500.00, '2027-03-15'),
(30, 'Horizon Cloud', 'Татьяна Петрова', 1050000.00, 997500.00, '2026-10-30'),
(31, 'Quantum Analytics', 'Алексей Кузнецов', 1420000.00, 1349000.00, '2027-01-25'),
(32, 'Nova Portal', 'Мария Смирнова', 3150000.00, 2992500.00, '2026-12-10'),
(33, 'Pioneer Dashboard', 'Иван Попов', 770000.00, 693000.00, '2026-08-05'),
(34, 'Vanguard AI', 'Елена Васильева', 1880000.00, 1786000.00, '2027-04-20'),
(35, 'Infinity ERP', 'Дмитрий Фёдоров', 920000.00, 828000.00, '2026-11-28'),
(36, 'Zenith CRM', 'Ольга Морозова', 2340000.00, 2223000.00, '2027-02-17'),
(37, 'Orion Mobile', 'Сергей Никитин', 650000.00, 585000.00, '2026-09-20'),
(38, 'Aurora Platform', 'Анна Иванова', 1760000.00, 1672000.00, '2027-03-08'),
(39, 'Catalyst System', 'Андрей Петров', 2890000.00, 2745500.00, '2026-10-14'),
(40, 'Synergy Solution', 'Татьяна Сидорова', 840000.00, 756000.00, '2026-12-22'),
(41, 'Alpha Initiative', 'Алексей Смирнов', 1320000.00, 1254000.00, '2027-01-15'),
(42, 'Beta Project', 'Мария Попова', 3050000.00, 2897500.00, '2026-08-28'),
(43, 'Gamma Program', 'Иван Васильев', 710000.00, 639000.00, '2026-11-07'),
(44, 'Delta Module', 'Елена Фёдорова', 1980000.00, 1881000.00, '2027-04-05'),
(45, 'Epsilon Network', 'Дмитрий Морозов', 860000.00, 774000.00, '2026-09-25'),
(46, 'Nexus Engine', 'Ольга Никитина', 2560000.00, 2432000.00, '2027-02-22'),
(47, 'Vertex Suite', 'Сергей Иванов', 990000.00, 891000.00, '2026-10-10'),
(48, 'Apex Hub', 'Анна Петрова', 1670000.00, 1586500.00, '2027-03-18'),
(49, 'Summit Cloud', 'Андрей Сидоров', 3250000.00, 3087500.00, '2026-12-15'),
(50, 'Horizon Analytics', 'Татьяна Кузнецова', 730000.00, 657000.00, '2026-08-12'),
(51, 'Quantum Portal', 'Алексей Смирнова', 1450000.00, 1377500.00, '2027-01-30'),
(52, 'Nova Dashboard', 'Мария Попов', 2980000.00, 2831000.00, '2026-11-20'),
(53, 'Pioneer AI', 'Иван Васильева', 680000.00, 612000.00, '2026-09-05'),
(54, 'Vanguard ERP', 'Елена Фёдоров', 1820000.00, 1729000.00, '2027-04-10'),
(55, 'Infinity CRM', 'Дмитрий Морозова', 910000.00, 819000.00, '2026-10-28'),
(56, 'Zenith Mobile', 'Ольга Никитин', 2420000.00, 2299000.00, '2027-02-12'),
(57, 'Orion Platform', 'Сергей Иванова', 760000.00, 684000.00, '2026-12-03'),
(58, 'Aurora System', 'Анна Петров', 1730000.00, 1643500.00, '2027-03-25'),
(59, 'Catalyst Framework', 'Андрей Сидорова', 2850000.00, 2707500.00, '2026-08-20'),
(60, 'Synergy Project', 'Татьяна Кузнецов', 820000.00, 738000.00, '2026-11-12'),
(61, 'Alpha Program', 'Алексей Васильев', 1290000.00, 1225500.00, '2027-01-22'),
(62, 'Beta Module', 'Мария Фёдорова', 3120000.00, 2964000.00, '2026-10-15'),
(63, 'Gamma Network', 'Иван Морозов', 690000.00, 621000.00, '2026-12-28'),
(64, 'Delta Engine', 'Елена Никитина', 1950000.00, 1852500.00, '2027-04-18'),
(65, 'Epsilon Suite', 'Дмитрий Иванов', 870000.00, 783000.00, '2026-09-18'),
(66, 'Nexus Hub', 'Ольга Петрова', 2580000.00, 2451000.00, '2027-02-05'),
(67, 'Vertex Cloud', 'Сергей Сидоров', 940000.00, 846000.00, '2026-11-25'),
(68, 'Apex Analytics', 'Анна Кузнецова', 1620000.00, 1539000.00, '2027-03-12'),
(69, 'Summit Portal', 'Андрей Смирнов', 3280000.00, 3116000.00, '2026-08-10'),
(70, 'Horizon Dashboard', 'Татьяна Попова', 750000.00, 675000.00, '2026-10-20'),
(71, 'Quantum AI', 'Алексей Васильева', 1480000.00, 1406000.00, '2027-01-10'),
(72, 'Nova ERP', 'Мария Фёдоров', 2920000.00, 2774000.00, '2026-12-20'),
(73, 'Pioneer CRM', 'Иван Морозова', 660000.00, 594000.00, '2026-09-08'),
(74, 'Vanguard Mobile', 'Елена Никитин', 1850000.00, 1757500.00, '2027-04-25'),
(75, 'Infinity Platform', 'Дмитрий Иванова', 900000.00, 810000.00, '2026-11-02'),
(76, 'Zenith System', 'Ольга Петров', 2380000.00, 2261000.00, '2027-02-28'),
(77, 'Orion Framework', 'Сергей Сидорова', 720000.00, 648000.00, '2026-10-05'),
(78, 'Aurora Project', 'Анна Кузнецов', 1700000.00, 1615000.00, '2027-03-20'),
(79, 'Catalyst Program', 'Андрей Смирнова', 2820000.00, 2679000.00, '2026-08-25'),
(80, 'Synergy Module', 'Татьяна Попов', 810000.00, 729000.00, '2026-12-12'),
(81, 'Alpha Network', 'Алексей Фёдорова', 1270000.00, 1206500.00, '2027-01-18'),
(82, 'Beta Engine', 'Мария Морозов', 3080000.00, 2926000.00, '2026-11-15'),
(83, 'Gamma Suite', 'Иван Никитина', 670000.00, 603000.00, '2026-09-22'),
(84, 'Delta Hub', 'Елена Иванов', 1920000.00, 1824000.00, '2027-04-08'),
(85, 'Epsilon Cloud', 'Дмитрий Петрова', 890000.00, 801000.00, '2026-10-12'),
(86, 'Nexus Analytics', 'Ольга Сидоров', 2540000.00, 2413000.00, '2027-02-15'),
(87, 'Vertex Portal', 'Сергей Кузнецова', 930000.00, 837000.00, '2026-12-08'),
(88, 'Apex Dashboard', 'Анна Смирнов', 1590000.00, 1510500.00, '2027-03-05'),
(89, 'Summit AI', 'Андрей Попова', 3220000.00, 3059000.00, '2026-08-18'),
(90, 'Horizon ERP', 'Татьяна Васильев', 740000.00, 666000.00, '2026-11-28'),
(91, 'Quantum CRM', 'Алексей Фёдоров', 1460000.00, 1387000.00, '2027-01-28'),
(92, 'Nova Mobile', 'Мария Морозова', 2950000.00, 2802500.00, '2026-10-22'),
(93, 'Pioneer Platform', 'Иван Никитин', 650000.00, 585000.00, '2026-09-15'),
(94, 'Vanguard System', 'Елена Иванова', 1870000.00, 1776500.00, '2027-04-15'),
(95, 'Infinity Framework', 'Дмитрий Петров', 880000.00, 792000.00, '2026-12-25'),
(96, 'Zenith Project', 'Ольга Сидорова', 2360000.00, 2242000.00, '2027-02-20'),
(97, 'Orion Program', 'Сергей Кузнецов', 710000.00, 639000.00, '2026-11-05'),
(98, 'Aurora Module', 'Анна Смирнова', 1720000.00, 1634000.00, '2027-03-10'),
(99, 'Catalyst Network', 'Андрей Попов', 2800000.00, 2660000.00, '2026-08-30'),
(100, 'Synergy Engine', 'Татьяна Васильева', 800000.00, 720000.00, '2026-10-18')]

# %%
def create_database():
    conn = sqlite3.connect('company_data.db')
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS projects (
            project_id INTEGER PRIMARY KEY,
            project_name TEXT NOT NULL,
            manager TEXT NOT NULL,
            budget REAL NOT NULL,
            spent REAL NOT NULL,
            deadline TEXT NOT NULL
        )
    ''')
    cursor.executemany('''
        INSERT INTO projects (project_id, project_name, manager, budget, spent, deadline)
        VALUES (?, ?, ?, ?, ?, ?)
    ''', data)
    conn.commit()
    conn.close()

# %%
create_database()
